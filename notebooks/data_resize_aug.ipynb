# %%
from tensorflow import keras as K
from tensorflow.keras import applications

# %%
# import libraries
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions, preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
from tensorflow.keras.preprocessing import image # Keras own inbuild image class
from tensorflow.keras.layers import Dense,Dropout,GlobalAveragePooling2D,Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential,Input,Model

import numpy as np
import matplotlib.pyplot as plt

from PIL import ImageEnhance, ImageFilter
import random
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Activation, Flatten

from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, save_img

# %%
from PIL import Image, ImageOps

# %% [markdown]
# # Resize Images and Add Padding

# %%
# Desired target size for all images
target_size = (416, 416)
padding_color = (0, 0, 0) #black

# Function to resize and add padding 
def resize_pad_images(parent_folder, target_size, padding_color):
    # Iterate through each class folder
    for class_folder in os.listdir(parent_folder):
        class_folder_path = os.path.join(parent_folder, class_folder)

        # Check if it's a directory
        if os.path.isdir(class_folder_path):
            print(f"Processing folder: {class_folder_path}")

            # Iterate over each image file in the class folder
            for img_name in os.listdir(class_folder_path):
                img_path = os.path.join(class_folder_path, img_name)

                if img_name.endswith(('.png', '.jpg', '.jpeg')):  # Check for valid image files
                    print(f"Processing image: {img_path}")

                    img = Image.open(img_path)

                    # Resize while keeping the aspect ratio
                    img.thumbnail(target_size, Image.Resampling.LANCZOS)

                    # Calculate padding to center the image
                    delta_w = target_size[0] - img.size[0]
                    delta_h = target_size[1] - img.size[1]
                    padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))

                     # Add padding
                    img_padded = ImageOps.expand(img, padding, fill=padding_color)

                    # Save the resized and padded image
                    img_padded.save(img_path)
                    print(f"Saved image: {img_path}")

# %%
# Paths to the train, test, and valid folders
train_folder = '../data/train/'
test_folder = '../data/test/'
valid_folder = '../data/valid/'

# %%
# Apply resizing and padding to all folders
print("Processing train folder...")
resize_pad_images(train_folder, target_size, padding_color)

print("Processing test folder...")
resize_pad_images(test_folder, target_size, padding_color)

print("Processing valid folder...")
resize_pad_images(valid_folder, target_size, padding_color)
# Out:
# Processing train folder...
# Processing folder: ../data/train/Aphids
# Processing image: ../data/train/Aphids\00_aphids_train.jpg
# Saved image: ../data/train/Aphids\00_aphids_train.jpg
# Processing image: ../data/train/Aphids\01_aphids_train.jpg
# Saved image: ../data/train/Aphids\01_aphids_train.jpg
# Processing image: ../data/train/Aphids\02_aphids_train.jpg
# Saved image: ../data/train/Aphids\02_aphids_train.jpg
# Processing image: ../data/train/Aphids\03_aphids_train.jpg
# Saved image: ../data/train/Aphids\03_aphids_train.jpg
# Processing image: ../data/train/Aphids\04_aphids_train.jpg
# Saved image: ../data/train/Aphids\04_aphids_train.jpg
# Processing image: ../data/train/Aphids\05_aphids_train.jpg
# Saved image: ../data/train/Aphids\05_aphids_train.jpg
# Processing image: ../data/train/Aphids\06_aphids_train.jpg
# Saved image: ../data/train/Aphids\06_aphids_train.jpg
# Processing image: ../data/train/Aphids\07_aphids_train.jpg
# Saved image: ../data/train/Aphids\07_aphids_train.jpg
# Processing image: ../data/train/Aphids\08_aphids_train.jpg
# Saved image: ../data/train/Aphids\08_aphids_train.jpg
# Processing image: ../data/train/Aphids\09_aphids_train.jpg
# Saved image: ../data/train/Aphids\09_aphids_train.jpg
# Processing folder: ../data/train/Botrytis
# Processing image: ../data/train/Botrytis\00_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\00_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\01_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\01_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\02_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\02_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\03_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\03_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\04_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\04_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\05_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\05_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\06_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\06_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\07_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\07_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\08_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\08_botrytis_train.jpg
# Processing image: ../data/train/Botrytis\09_botrytis_train.jpg
# Saved image: ../data/train/Botrytis\09_botrytis_train.jpg
# Processing folder: ../data/train/Dehydration
# Processing image: ../data/train/Dehydration\00_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\00_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\01_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\01_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\02_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\02_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\03_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\03_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\04_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\04_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\05_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\05_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\06_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\06_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\07_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\07_dehydration_train.jpg
# Processing image: ../data/train/Dehydration\08_dehydration_train.jpg
# Saved image: ../data/train/Dehydration\08_dehydration_train.jpg
# Processing folder: ../data/train/Healthy
# Processing image: ../data/train/Healthy\00_healthy_train.jpg
# Saved image: ../data/train/Healthy\00_healthy_train.jpg
# Processing image: ../data/train/Healthy\01_healthy_train.jpg
# Saved image: ../data/train/Healthy\01_healthy_train.jpg
# Processing image: ../data/train/Healthy\02_healthy_train.jpg
# Saved image: ../data/train/Healthy\02_healthy_train.jpg
# Processing image: ../data/train/Healthy\03_healthy_train.jpg
# Saved image: ../data/train/Healthy\03_healthy_train.jpg
# Processing image: ../data/train/Healthy\04_healthy_train.jpg
# Saved image: ../data/train/Healthy\04_healthy_train.jpg
# Processing image: ../data/train/Healthy\05_healthy_train.jpg
# Saved image: ../data/train/Healthy\05_healthy_train.jpg
# Processing image: ../data/train/Healthy\06_healthy_train.jpg
# Saved image: ../data/train/Healthy\06_healthy_train.jpg
# Processing image: ../data/train/Healthy\07_healthy_train.jpg
# Saved image: ../data/train/Healthy\07_healthy_train.jpg
# Processing image: ../data/train/Healthy\08_healthy_train.jpg
# Saved image: ../data/train/Healthy\08_healthy_train.jpg
# Processing image: ../data/train/Healthy\09_healthy_train.jpg
# Saved image: ../data/train/Healthy\09_healthy_train.jpg
# Processing folder: ../data/train/Leaf Miners
# Processing image: ../data/train/Leaf Miners\00_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\00_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\01_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\01_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\02_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\02_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\03_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\03_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\04_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\04_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\05_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\05_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\06_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\06_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\07_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\07_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\08_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\08_leaf_miners_train.jpg
# Processing image: ../data/train/Leaf Miners\09_leaf_miners_train.jpg
# Saved image: ../data/train/Leaf Miners\09_leaf_miners_train.jpg
# Processing folder: ../data/train/Nitrogen Deficiency
# Processing image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train.jpg
# Processing image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train.jpg
# Saved image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train.jpg
# Processing folder: ../data/train/Nutrient Burn
# Processing image: ../data/train/Nutrient Burn\00_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\00_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\01_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\01_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\02_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\02_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\03_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\03_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\04_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\04_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\05_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\05_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\06_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\06_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\07_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\07_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\08_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\08_nutrient_burn_train.jpg
# Processing image: ../data/train/Nutrient Burn\09_nutrient_burn_train.jpg
# Saved image: ../data/train/Nutrient Burn\09_nutrient_burn_train.jpg
# Processing folder: ../data/train/Overwatering
# Processing image: ../data/train/Overwatering\00_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\00_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\01_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\01_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\02_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\02_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\03_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\03_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\04_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\04_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\05_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\05_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\06_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\06_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\07_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\07_overwatering_train.jpg
# Processing image: ../data/train/Overwatering\08_overwatering_train.jpg
# Saved image: ../data/train/Overwatering\08_overwatering_train.jpg
# Processing folder: ../data/train/PH Fluctuation
# Processing image: ../data/train/PH Fluctuation\00_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\00_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\01_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\01_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\02_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\02_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\03_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\03_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\04_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\04_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\05_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\05_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\06_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\06_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\07_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\07_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\08_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\08_ph_fluctuation_train.jpg
# Processing image: ../data/train/PH Fluctuation\09_ph_fluctuation_train.jpg
# Saved image: ../data/train/PH Fluctuation\09_ph_fluctuation_train.jpg
# Processing folder: ../data/train/Phosphorus Deficiency
# Processing image: ../data/train/Phosphorus Deficiency\00_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\00_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\01_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\01_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\02_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\02_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\03_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\03_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\04_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\04_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\05_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\05_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\06_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\06_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\07_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\07_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\08_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\08_phosphorus_def_train.jpg
# Processing image: ../data/train/Phosphorus Deficiency\09_phosphorus_def_train.jpg
# Saved image: ../data/train/Phosphorus Deficiency\09_phosphorus_def_train.jpg
# Processing folder: ../data/train/Potassium Deficiency
# Processing image: ../data/train/Potassium Deficiency\00_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\00_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\01_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\01_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\02_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\02_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\03_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\03_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\04_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\04_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\05_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\05_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\06_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\06_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\07_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\07_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\08_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\08_potassium_def_train.jpg
# Processing image: ../data/train/Potassium Deficiency\09_potassium_def_train.jpg
# Saved image: ../data/train/Potassium Deficiency\09_potassium_def_train.jpg
# Processing folder: ../data/train/Powdery Mildew
# Processing image: ../data/train/Powdery Mildew\00_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\00_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\01_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\01_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\02_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\02_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\03_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\03_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\04_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\04_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\05_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\05_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\06_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\06_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\07_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\07_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\08_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\08_powdery_mildew_train.jpg
# Processing image: ../data/train/Powdery Mildew\09_powdery_mildew_train.jpg
# Saved image: ../data/train/Powdery Mildew\09_powdery_mildew_train.jpg
# Processing folder: ../data/train/Septoria
# Processing image: ../data/train/Septoria\00_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\00_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\01_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\01_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\02_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\02_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\03_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\03_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\04_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\04_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\05_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\05_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\06_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\06_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\07_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\07_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\08_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\08_septoria_yellowleaf_train.jpg
# Processing image: ../data/train/Septoria\09_septoria_yellowleaf_train.jpg
# Saved image: ../data/train/Septoria\09_septoria_yellowleaf_train.jpg
# Processing test folder...
# Processing folder: ../data/test/Aphids
# Processing image: ../data/test/Aphids\00_aphids_test.jpg
# Saved image: ../data/test/Aphids\00_aphids_test.jpg
# Processing image: ../data/test/Aphids\01_aphids_test.jpg
# Saved image: ../data/test/Aphids\01_aphids_test.jpg
# Processing folder: ../data/test/Botrytis
# Processing image: ../data/test/Botrytis\00_botrytis_test.jpg
# Saved image: ../data/test/Botrytis\00_botrytis_test.jpg
# Processing image: ../data/test/Botrytis\01_botrytis_test.jpg
# Saved image: ../data/test/Botrytis\01_botrytis_test.jpg
# Processing folder: ../data/test/Dehydration
# Processing image: ../data/test/Dehydration\00_dehydration_test.jpg
# Saved image: ../data/test/Dehydration\00_dehydration_test.jpg
# Processing image: ../data/test/Dehydration\01_dehydration_test.jpg
# Saved image: ../data/test/Dehydration\01_dehydration_test.jpg
# Processing folder: ../data/test/Healthy
# Processing image: ../data/test/Healthy\00_healthy_test.jpg
# Saved image: ../data/test/Healthy\00_healthy_test.jpg
# Processing image: ../data/test/Healthy\01_healthy_test.jpg
# Saved image: ../data/test/Healthy\01_healthy_test.jpg
# Processing folder: ../data/test/Leaf Miners
# Processing image: ../data/test/Leaf Miners\00_leaf_miners_test.jpg
# Saved image: ../data/test/Leaf Miners\00_leaf_miners_test.jpg
# Processing image: ../data/test/Leaf Miners\01_leaf_miners_test.jpg
# Saved image: ../data/test/Leaf Miners\01_leaf_miners_test.jpg
# Processing folder: ../data/test/Nitrogen Deficiency
# Processing image: ../data/test/Nitrogen Deficiency\00_nitrogen_def_test.jpg
# Saved image: ../data/test/Nitrogen Deficiency\00_nitrogen_def_test.jpg
# Processing image: ../data/test/Nitrogen Deficiency\01_nitrogen_def_test.jpg
# Saved image: ../data/test/Nitrogen Deficiency\01_nitrogen_def_test.jpg
# Processing folder: ../data/test/Nutrient Burn
# Processing image: ../data/test/Nutrient Burn\00_nutrient_burn_test.jpg
# Saved image: ../data/test/Nutrient Burn\00_nutrient_burn_test.jpg
# Processing image: ../data/test/Nutrient Burn\01_nutrient_burn_test.jpg
# Saved image: ../data/test/Nutrient Burn\01_nutrient_burn_test.jpg
# Processing folder: ../data/test/Overwatering
# Processing image: ../data/test/Overwatering\00_overwatering_test.jpg
# Saved image: ../data/test/Overwatering\00_overwatering_test.jpg
# Processing image: ../data/test/Overwatering\01_overwatering_test.jpg
# Saved image: ../data/test/Overwatering\01_overwatering_test.jpg
# Processing folder: ../data/test/PH Fluctuation
# Processing image: ../data/test/PH Fluctuation\00_ph_fluctuation_test.jpg
# Saved image: ../data/test/PH Fluctuation\00_ph_fluctuation_test.jpg
# Processing image: ../data/test/PH Fluctuation\01_ph_fluctuation_test.jpg
# Saved image: ../data/test/PH Fluctuation\01_ph_fluctuation_test.jpg
# Processing folder: ../data/test/Phosphorus Deficiency
# Processing image: ../data/test/Phosphorus Deficiency\00_phosphorus_def_test.jpg
# Saved image: ../data/test/Phosphorus Deficiency\00_phosphorus_def_test.jpg
# Processing image: ../data/test/Phosphorus Deficiency\01_phosphorus_def_test.jpg
# Saved image: ../data/test/Phosphorus Deficiency\01_phosphorus_def_test.jpg
# Processing folder: ../data/test/Potassium Deficiency
# Processing image: ../data/test/Potassium Deficiency\00_potassium_def_test.jpg
# Saved image: ../data/test/Potassium Deficiency\00_potassium_def_test.jpg
# Processing image: ../data/test/Potassium Deficiency\02_potassium_def_test.jpg
# Saved image: ../data/test/Potassium Deficiency\02_potassium_def_test.jpg
# Processing folder: ../data/test/Powdery Mildew
# Processing image: ../data/test/Powdery Mildew\00_powdery_mildew_test.png
# Saved image: ../data/test/Powdery Mildew\00_powdery_mildew_test.png
# Processing image: ../data/test/Powdery Mildew\01_powdery_mildew_test.png
# Saved image: ../data/test/Powdery Mildew\01_powdery_mildew_test.png
# Processing folder: ../data/test/Septoria
# Processing image: ../data/test/Septoria\00_septoria_yellowleaf_test.jpg
# Saved image: ../data/test/Septoria\00_septoria_yellowleaf_test.jpg
# Processing image: ../data/test/Septoria\01_septoria_yellowleaf_test.jpg
# Saved image: ../data/test/Septoria\01_septoria_yellowleaf_test.jpg
# Processing valid folder...
# Processing folder: ../data/valid/Aphids
# Processing image: ../data/valid/Aphids\00_aphids_valid.jpg
# Saved image: ../data/valid/Aphids\00_aphids_valid.jpg
# Processing image: ../data/valid/Aphids\01_aphids_valid.jpg
# Saved image: ../data/valid/Aphids\01_aphids_valid.jpg
# Processing folder: ../data/valid/Botrytis
# Processing image: ../data/valid/Botrytis\00_botrytis_valid.jpg
# Saved image: ../data/valid/Botrytis\00_botrytis_valid.jpg
# Processing image: ../data/valid/Botrytis\01_botrytis_valid.jpg
# Saved image: ../data/valid/Botrytis\01_botrytis_valid.jpg
# Processing folder: ../data/valid/Dehydration
# Processing image: ../data/valid/Dehydration\00_dehydration_valid.jpg
# Saved image: ../data/valid/Dehydration\00_dehydration_valid.jpg
# Processing image: ../data/valid/Dehydration\01_dehydration_valid.jpg
# Saved image: ../data/valid/Dehydration\01_dehydration_valid.jpg
# Processing folder: ../data/valid/Healthy
# Processing image: ../data/valid/Healthy\00_healthy_valid.jpg
# Saved image: ../data/valid/Healthy\00_healthy_valid.jpg
# Processing image: ../data/valid/Healthy\01_healthy_valid.jpg
# Saved image: ../data/valid/Healthy\01_healthy_valid.jpg
# Processing folder: ../data/valid/Leaf Miners
# Processing image: ../data/valid/Leaf Miners\00_leaf_miners_valid.jpg
# Saved image: ../data/valid/Leaf Miners\00_leaf_miners_valid.jpg
# Processing image: ../data/valid/Leaf Miners\01_leaf_miners_valid.jpg
# Saved image: ../data/valid/Leaf Miners\01_leaf_miners_valid.jpg
# Processing folder: ../data/valid/Nitrogen Deficiency
# Processing image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid.jpg
# Saved image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid.jpg
# Processing image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid.jpg
# Saved image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid.jpg
# Processing folder: ../data/valid/Nutrient Burn
# Processing image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid.jpg
# Saved image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid.jpg
# Processing image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid.jpg
# Saved image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid.jpg
# Processing folder: ../data/valid/Overwatering
# Processing image: ../data/valid/Overwatering\00_overwatering_valid.jpg
# Saved image: ../data/valid/Overwatering\00_overwatering_valid.jpg
# Processing image: ../data/valid/Overwatering\01_overwatering_valid.jpg
# Saved image: ../data/valid/Overwatering\01_overwatering_valid.jpg
# Processing folder: ../data/valid/PH Fluctuation
# Processing image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid.jpg
# Saved image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid.jpg
# Processing image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid.jpg
# Saved image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid.jpg
# Processing folder: ../data/valid/Phosphorus Deficiency
# Processing image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid.jpg
# Saved image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid.jpg
# Processing image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid.jpg
# Saved image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid.jpg
# Processing folder: ../data/valid/Potassium Deficiency
# Processing image: ../data/valid/Potassium Deficiency\00_potassium_def_valid.jpg
# Saved image: ../data/valid/Potassium Deficiency\00_potassium_def_valid.jpg
# Processing image: ../data/valid/Potassium Deficiency\01_potassium_def_valid.jpg
# Saved image: ../data/valid/Potassium Deficiency\01_potassium_def_valid.jpg
# Processing folder: ../data/valid/Powdery Mildew
# Processing image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid.png
# Saved image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid.png
# Processing image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid.png
# Saved image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid.png
# Processing folder: ../data/valid/Septoria
# Processing image: ../data/valid/Septoria\00_septoria_yellowleaf_valid.jpg
# Saved image: ../data/valid/Septoria\00_septoria_yellowleaf_valid.jpg
# Processing image: ../data/valid/Septoria\01_septoria_yellowleaf_valid.jpg
# Saved image: ../data/valid/Septoria\01_septoria_yellowleaf_valid.jpg

# %%
# folder names containing images of the things you want to classify
disease_classes = [
    'Aphids',
    'Botrytis',
    'Dehydration',
    'Healthy',
    'Leaf Miners',
    'Nitrogen Deficiency',
    'Nutrient Burn',
    'Overwatering',
    'PH Fluctuation',
    'Phosphorus Deficiency',
    'Potassium Deficiency',
    'Powdery Mildew',
    'Septoria']

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ### Random rotation between -40 to +40 degrees, random zoom in/out by 20%, random brightness between 80% and 120% were applied as data augmentation.

# %%
# define an image data generator
# Data augmentation: Applies random distortions and transformations to the images (only on your training data!).

data_gen = image.ImageDataGenerator(
    # define the preprocessing function that should be applied to all images
    # preprocessing_function=preprocess_input,
    fill_mode='nearest',
    rotation_range=40,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2]
)

# %%
from keras.preprocessing.image import img_to_array, load_img, array_to_img

# %%
# Function to apply augmentation and save images
def augment_images_in_folder(folder_path, target_num_images, datagen):
    for class_folder in os.listdir(folder_path):
        class_folder_path = os.path.join(folder_path, class_folder)

        if os.path.isdir(class_folder_path):
            print(f"Processing folder: {class_folder_path}")
            
            # Get all images in the class folder
            image_files = [f for f in os.listdir(class_folder_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
            num_existing_images = len(image_files)
            
            # Calculate how many images need to be generated
            num_to_generate = target_num_images - num_existing_images
            
            if num_to_generate > 0:
                print(f"Generating {num_to_generate} images for class {class_folder}")

                # Loop over the existing images and create augmented images
                generated = 0
                while generated < num_to_generate:
                    for img_name in image_files:
                        img_path = os.path.join(class_folder_path, img_name)
                        
                        # Load image and convert to array
                        img = load_img(img_path)
                        img_array = img_to_array(img)
                        img_array = np.expand_dims(img_array, axis=0)

                        # Generate a batch of augmented images
                        aug_iter = datagen.flow(img_array, batch_size=1)

                        # Save the augmented image with _aug appended to the filename
                        aug_img = next(aug_iter)[0].astype('uint8')
                        aug_img_pil = array_to_img(aug_img)

                        # Create new filename for augmented image
                        new_img_name = f"{os.path.splitext(img_name)[0]}_aug{generated}.jpg"
                        new_img_path = os.path.join(class_folder_path, new_img_name)

                        # Save the augmented image
                        aug_img_pil.save(new_img_path)
                        print(f"Saved augmented image: {new_img_path}")

                        generated += 1
                        if generated >= num_to_generate:
                            break

# %%
# Define target number of images per class
train_target_num_images = 100
valid_target_num_images = 20

# %%
# Apply augmentation to the train folder
print("Processing train folder...")
augment_images_in_folder(train_folder, train_target_num_images, data_gen)
# Out:
# Processing train folder...
# Processing folder: ../data/train/Aphids
# Generating 90 images for class Aphids
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug0.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug1.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug2.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug3.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug4.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug5.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug6.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug7.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug8.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug9.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug10.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug11.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug12.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug13.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug14.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug15.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug16.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug17.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug18.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug19.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug20.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug21.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug22.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug23.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug24.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug25.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug26.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug27.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug28.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug29.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug30.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug31.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug32.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug33.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug34.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug35.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug36.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug37.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug38.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug39.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug40.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug41.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug42.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug43.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug44.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug45.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug46.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug47.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug48.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug49.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug50.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug51.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug52.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug53.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug54.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug55.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug56.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug57.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug58.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug59.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug60.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug61.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_aug62.jpg
# Saved augmented image: ../data/train/Aphids\03_aphids_train_aug63.jpg
# Saved augmented image: ../data/train/Aphids\04_aphids_train_aug64.jpg
# Saved augmented image: ../data/train/Aphids\05_aphids_train_aug65.jpg
# Saved augmented image: ../data/train/Aphids\06_aphids_train_aug66.jpg
# Saved augmented image: ../data/train/Aphids\07_aphids_train_aug67.jpg
# Saved augmented image: ../data/train/Aphids\08_aphids_train_aug68.jpg
# Saved augmented image: ../data/train/Aphids\09_aphids_train_aug69.jpg
# Saved augmented image: ../data/train/Aphids\00_aphids_train_aug70.jpg
# Saved augmented image: ../data/train/Aphids\01_aphids_train_aug71.jpg
# Saved augmented image: ../data/train/Aphids\02_aphids_train_a
# Saved augmented image: ../data/train/Leaf Miners\05_leaf_miners_train_aug85.jpg
# Saved augmented image: ../data/train/Leaf Miners\06_leaf_miners_train_aug86.jpg
# Saved augmented image: ../data/train/Leaf Miners\07_leaf_miners_train_aug87.jpg
# Saved augmented image: ../data/train/Leaf Miners\08_leaf_miners_train_aug88.jpg
# Saved augmented image: ../data/train/Leaf Miners\09_leaf_miners_train_aug89.jpg
# Processing folder: ../data/train/Nitrogen Deficiency
# Generating 90 images for class Nitrogen Deficiency
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug0.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug1.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug2.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug3.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug4.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug5.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug6.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug7.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug8.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug9.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug10.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug11.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug12.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug13.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug14.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug15.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug16.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug17.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug18.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug19.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug20.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug21.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug22.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug23.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug24.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug25.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug26.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug27.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug28.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug29.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug30.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug31.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug32.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug33.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug34.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug35.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug36.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug37.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug38.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug39.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug40.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug41.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug42.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug43.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug44.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug45.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug46.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug47.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug48.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug49.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug50.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug51.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug52.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug53.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug54.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug55.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug56.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug57.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug58.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug59.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug60.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug61.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug62.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug63.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug64.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug65.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug66.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug67.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug68.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug69.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug70.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug71.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug72.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug73.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug74.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug75.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug76.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug77.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug78.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug79.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\00_nitrogen_def_train_aug80.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\01_nitrogen_def_train_aug81.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\02_nitrogen_def_train_aug82.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\03_nitrogen_def_train_aug83.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\04_nitrogen_def_train_aug84.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\05_nitrogen_def_train_aug85.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\06_nitrogen_def_train_aug86.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\07_nitrogen_def_train_aug87.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\08_nitrogen_def_train_aug88.jpg
# Saved augmented image: ../data/train/Nitrogen Deficiency\09_nitrogen_def_train_aug89.jpg
# Processing folder: ../data/train/Nutrient Burn
# Generating 90 images for class Nutrient Burn
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug0.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug1.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug2.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug3.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug4.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug5.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug6.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug7.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug8.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug9.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug10.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug11.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug12.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug13.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug14.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug15.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug16.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug17.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug18.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug19.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug20.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug21.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug22.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug23.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug24.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug25.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug26.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug27.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug28.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug29.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug30.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug31.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug32.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug33.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug34.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug35.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug36.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug37.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug38.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug39.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug40.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug41.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug42.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug43.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug44.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug45.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug46.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug47.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug48.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug49.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug50.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug51.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug52.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug53.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug54.jpg
# Saved augmented image: ../data/train/Nutrient Burn\05_nutrient_burn_train_aug55.jpg
# Saved augmented image: ../data/train/Nutrient Burn\06_nutrient_burn_train_aug56.jpg
# Saved augmented image: ../data/train/Nutrient Burn\07_nutrient_burn_train_aug57.jpg
# Saved augmented image: ../data/train/Nutrient Burn\08_nutrient_burn_train_aug58.jpg
# Saved augmented image: ../data/train/Nutrient Burn\09_nutrient_burn_train_aug59.jpg
# Saved augmented image: ../data/train/Nutrient Burn\00_nutrient_burn_train_aug60.jpg
# Saved augmented image: ../data/train/Nutrient Burn\01_nutrient_burn_train_aug61.jpg
# Saved augmented image: ../data/train/Nutrient Burn\02_nutrient_burn_train_aug62.jpg
# Saved augmented image: ../data/train/Nutrient Burn\03_nutrient_burn_train_aug63.jpg
# Saved augmented image: ../data/train/Nutrient Burn\04_nutrient_burn_train_aug64.jpg
# ...
# Saved augmented image: ../data/train/Potassium Deficiency\06_potassium_def_train_aug86.jpg
# Saved augmented image: ../data/train/Potassium Deficiency\07_potassium_def_train_aug87.jpg
# Saved augmented image: ../data/train/Potassium Deficiency\08_potassium_def_train_aug88.jpg
# Saved augmented image: ../data/train/Potassium Deficiency\09_potassium_def_train_aug89.jpg
# Processing folder: ../data/train/Powdery Mildew
# Generating 90 images for class Powdery Mildew
# Saved augmented image: ../data/train/Powdery Mildew\00_powdery_mildew_train_a
# Saved augmented image: ../data/train/Septoria\07_septoria_yellowleaf_train_aug87.jpg
# Saved augmented image: ../data/train/Septoria\08_septoria_yellowleaf_train_aug88.jpg
# Saved augmented image: ../data/train/Septoria\09_septoria_yellowleaf_train_aug89.jpg

# %%
# Apply augmentation to the train folder
print("Processing valid folder...")
augment_images_in_folder(valid_folder, valid_target_num_images, data_gen)
# Out:
# Processing valid folder...
# Processing folder: ../data/valid/Aphids
# Generating 18 images for class Aphids
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug0.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug1.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug2.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug3.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug4.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug5.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug6.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug7.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug8.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug9.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug10.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug11.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug12.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug13.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug14.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug15.jpg
# Saved augmented image: ../data/valid/Aphids\00_aphids_valid_aug16.jpg
# Saved augmented image: ../data/valid/Aphids\01_aphids_valid_aug17.jpg
# Processing folder: ../data/valid/Botrytis
# Generating 18 images for class Botrytis
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug0.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug1.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug2.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug3.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug4.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug5.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug6.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug7.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug8.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug9.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug10.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug11.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug12.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug13.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug14.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug15.jpg
# Saved augmented image: ../data/valid/Botrytis\00_botrytis_valid_aug16.jpg
# Saved augmented image: ../data/valid/Botrytis\01_botrytis_valid_aug17.jpg
# Processing folder: ../data/valid/Dehydration
# Generating 18 images for class Dehydration
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug0.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug1.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug2.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug3.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug4.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug5.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug6.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug7.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug8.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug9.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug10.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug11.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug12.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug13.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug14.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug15.jpg
# Saved augmented image: ../data/valid/Dehydration\00_dehydration_valid_aug16.jpg
# Saved augmented image: ../data/valid/Dehydration\01_dehydration_valid_aug17.jpg
# Processing folder: ../data/valid/Healthy
# Generating 18 images for class Healthy
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug0.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug1.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug2.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug3.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug4.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug5.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug6.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug7.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug8.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug9.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug10.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug11.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug12.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug13.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug14.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug15.jpg
# Saved augmented image: ../data/valid/Healthy\00_healthy_valid_aug16.jpg
# Saved augmented image: ../data/valid/Healthy\01_healthy_valid_aug17.jpg
# Processing folder: ../data/valid/Leaf Miners
# Generating 18 images for class Leaf Miners
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug0.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug1.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug2.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug3.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug4.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug5.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug6.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug7.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug8.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug9.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug10.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug11.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug12.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug13.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug14.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug15.jpg
# Saved augmented image: ../data/valid/Leaf Miners\00_leaf_miners_valid_aug16.jpg
# Saved augmented image: ../data/valid/Leaf Miners\01_leaf_miners_valid_aug17.jpg
# Processing folder: ../data/valid/Nitrogen Deficiency
# Generating 18 images for class Nitrogen Deficiency
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug0.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug1.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug2.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug3.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug4.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug5.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug6.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug7.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug8.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug9.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug10.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug11.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug12.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug13.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug14.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug15.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\00_nitrogen_def_valid_aug16.jpg
# Saved augmented image: ../data/valid/Nitrogen Deficiency\01_nitrogen_def_valid_aug17.jpg
# Processing folder: ../data/valid/Nutrient Burn
# Generating 18 images for class Nutrient Burn
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug0.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug1.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug2.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug3.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug4.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug5.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug6.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug7.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug8.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug9.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug10.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug11.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug12.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug13.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug14.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug15.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\00_nutrient_burn_valid_aug16.jpg
# Saved augmented image: ../data/valid/Nutrient Burn\01_nutrient_burn_valid_aug17.jpg
# Processing folder: ../data/valid/Overwatering
# Generating 18 images for class Overwatering
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug0.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug1.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug2.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug3.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug4.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug5.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug6.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug7.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug8.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug9.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug10.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug11.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug12.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug13.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug14.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug15.jpg
# Saved augmented image: ../data/valid/Overwatering\00_overwatering_valid_aug16.jpg
# Saved augmented image: ../data/valid/Overwatering\01_overwatering_valid_aug17.jpg
# Processing folder: ../data/valid/PH Fluctuation
# Generating 18 images for class PH Fluctuation
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug0.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug1.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug2.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug3.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug4.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug5.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug6.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug7.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug8.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug9.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug10.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug11.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug12.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug13.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug14.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug15.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\00_ph_fluctuation_valid_aug16.jpg
# Saved augmented image: ../data/valid/PH Fluctuation\01_ph_fluctuation_valid_aug17.jpg
# Processing folder: ../data/valid/Phosphorus Deficiency
# Generating 18 images for class Phosphorus Deficiency
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug0.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug1.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug2.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug3.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug4.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug5.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug6.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug7.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug8.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug9.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug10.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug11.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug12.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug13.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug14.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug15.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\00_phosphorus_def_valid_aug16.jpg
# Saved augmented image: ../data/valid/Phosphorus Deficiency\01_phosphorus_def_valid_aug17.jpg
# Processing folder: ../data/valid/Potassium Deficiency
# Generating 18 images for class Potassium Deficiency
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug0.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug1.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug2.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug3.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug4.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug5.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug6.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug7.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug8.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug9.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug10.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug11.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug12.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug13.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug14.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug15.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\00_potassium_def_valid_aug16.jpg
# Saved augmented image: ../data/valid/Potassium Deficiency\01_potassium_def_valid_aug17.jpg
# Processing folder: ../data/valid/Powdery Mildew
# Generating 18 images for class Powdery Mildew
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug0.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug1.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug2.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug3.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug4.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug5.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug6.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug7.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug8.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug9.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug10.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug11.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug12.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug13.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug14.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug15.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\00_powdery_mildew_valid_aug16.jpg
# Saved augmented image: ../data/valid/Powdery Mildew\01_powdery_mildew_valid_aug17.jpg
# Processing folder: ../data/valid/Septoria
# Generating 18 images for class Septoria
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug0.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug1.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug2.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug3.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug4.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug5.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug6.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug7.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug8.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug9.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug10.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug11.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug12.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug13.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug14.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug15.jpg
# Saved augmented image: ../data/valid/Septoria\00_septoria_yellowleaf_valid_aug16.jpg
# Saved augmented image: ../data/valid/Septoria\01_septoria_yellowleaf_valid_aug17.jpg

# %%
print(disease_classes)
# Out:
# ['Aphids', 'Botrytis', 'Dehydration', 'Healthy', 'Leaf Miners', 'Nitrogen Deficiency', 'Nutrient Burn', 'Overwatering', 'PH Fluctuation', 'Phosphorus Deficiency', 'Potassium Deficiency', 'Powdery Mildew', 'Septoria']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_folder,
    target_size=(416, 416),  # Resize images
    batch_size=32,
    class_mode='categorical',      # Use 'sparse' for integer labels
    shuffle=True              # Shuffle the data
)

valid_generator = valid_datagen.flow_from_directory(
    valid_folder,
    target_size=(416, 416),
    batch_size=32,
    class_mode='categorical',
    shuffle=False    
)
# Out:
# Found 1300 images belonging to 13 classes.
# Found 260 images belonging to 13 classes.

# %%
# Print class indices
print("Class indices for training data:")
print(train_generator.class_indices)
# Out:
# Class indices for training data:
# {'Aphids': 0, 'Botrytis': 1, 'Dehydration': 2, 'Healthy': 3, 'Leaf Miners': 4, 'Nitrogen Deficiency': 5, 'Nutrient Burn': 6, 'Overwatering': 7, 'PH Fluctuation': 8, 'Phosphorus Deficiency': 9, 'Potassium Deficiency': 10, 'Powdery Mildew': 11, 'Septoria': 12}
